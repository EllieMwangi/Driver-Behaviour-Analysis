# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
driving_data = pd.read_csv(r'E:\Envirocar\analysis\Driving Data(KIA SOUL)_(150728-160714)_(10 Drivers_A-J).csv',
                           usecols=['Absolute_throttle_position','Engine_speed','Calculated_LOAD_value','Vehicle_speed','Time(s)',
                                    'Class'])

# %%
driving_data.head()
# Out:
#    Absolute_throttle_position  Engine_speed  Calculated_LOAD_value  \
# 0                        13.3           929                   23.9
# 1                        13.7           726                   30.6
# 2                        13.7           685                   31.8
# 3                        13.3           675                   29.0
# 4                        13.7           716                   30.2
#
#    Vehicle_speed  Time(s) Class
# 0              0        1     A
# 1              0        2     A
# 2              0        3     A
# 3              0        4     A
# 4              0        5     A

# %%
driving_data.describe()
# Out:
#        Absolute_throttle_position  Engine_speed  Calculated_LOAD_value  \
# count                94380.000000  94380.000000            94380.00000
# mean                    19.362277   1422.838885               42.30515
# std                     12.079046    613.428059               18.38917
# min                     12.500000      0.000000                0.00000
# 25%                     14.500000    823.000000               27.10000
# 50%                     15.300000   1473.000000               41.60000
# 75%                     19.200000   1878.000000               51.00000
# max                     84.300000   6253.000000               98.40000
#
#        Vehicle_speed       Time(s)
# count   94380.000000  94380.000000
# mean       28.518881   1110.031765
# std        25.309664    683.042550
# min         0.000000      1.000000
# 25%         4.000000    537.000000
# 50%        23.000000   1073.000000
# 75%        51.000000   1616.000000
# max       129.000000   2948.000000

# %%
driving_data['Class'].describe()
# Out:
# count     94380
# unique       10
# top           D
# freq      13244
# Name: Class, dtype: object

# %%
driving_data['Vehicle_speed'].describe()
# Out:
# count    94380.000000
# mean        28.518881
# std         25.309664
# min          0.000000
# 25%          4.000000
# 50%         23.000000
# 75%         51.000000
# max        129.000000
# Name: Vehicle_speed, dtype: float64

# %%
driving_data['Class'].hist()

# %%
# Section the data according to drivers
driver_A = driving_data[driving_data['Class']=='A']
driver_B = driving_data[driving_data['Class']=='B']
driver_C = driving_data[driving_data['Class']=='C']
driver_D = driving_data[driving_data['Class']=='D']
driver_E = driving_data[driving_data['Class']=='E']
driver_F = driving_data[driving_data['Class']=='F']
driver_G = driving_data[driving_data['Class']=='G']
driver_H = driving_data[driving_data['Class']=='H']
driver_I = driving_data[driving_data['Class']=='I']
driver_J = driving_data[driving_data['Class']=='J']

# %%
#driver_A.describe()
driver_A.tail()
# Out:
#        Absolute_throttle_position  Engine_speed  Calculated_LOAD_value  \
# 88859                        14.1           660                   43.5
# 88860                        14.1           662                   43.9
# 88861                        14.1           666                   43.9
# 88862                        13.7           672                   43.9
# 88863                        12.9           212                    0.0
#
#        Vehicle_speed  Time(s) Class
# 88859              0     2012     A
# 88860              0     2013     A
# 88861              0     2014     A
# 88862              0     2015     A
# 88863              0     2016     A

# %%
#driver_A.info()
#Check for any missing values
driver_A.isnull().values.any()
# Out:
# False

# %%
plt.style.use('ggplot')
pd.plotting.scatter_matrix(driver_A, alpha=0.3, figsize = [10,10], s=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001374410E2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000137441C30B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000137441F4320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000137442208D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001374424FE80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000013744288470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000137442B8A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000137442EAFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000137442F9080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000013744359B38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000013744397128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000137443C66D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000137443F9C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000013744435278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000013744467828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001374449BDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000137444D63C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000013744509978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001374453BF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000013744577518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000137445A7AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000137445E80B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000013744618668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000013744646C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000013744688208>]],
#       dtype=object)

# %%
# Seaborn scatter matrix
g = sns.PairGrid(driver_A)
g = g.map(plt.scatter)

# %%
g = sns.PairGrid(driver_A)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
#Speed distribution across the trip
ax = sns.lineplot(x='Time(s)',y='Vehicle_speed',data=driver_A)

# %%
#Absolute Load distribution across trip
x = sns.lineplot(x='Time(s)',y='Absolute_throttle_position',data=driver_A)

# %%
#Engine Load distribution across trip
ax = sns.lineplot(x='Time(s)',y='Calculated_LOAD_value',data=driver_A)

# %%
throttle_vs_load = sns.relplot(x='Calculated_LOAD_value',y='Absolute_throttle_position',kind='line',data=driver_A)

# %%
driver_A.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row0_col1 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row0_col2 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row0_col3 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row1_col0 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row1_col2 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row1_col3 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row2_col0 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row2_col1 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row2_col3 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row3_col0 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row3_col1 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row3_col4 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row4_col0 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row4_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row4_col3 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Absolute_throttle_position</th>        <th class="col_heading level0 col1" >Engine_speed</th>        <th class="col_heading level0 col2" >Calculated_LOAD_value</th>        <th class="col_heading level0 col3" >Vehicle_speed</th>        <th class="col_heading level0 col4" >Time(s)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9level0_row0" class="row_heading level0 row0" >Absolute_throttle_position</th>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row0_col0" class="data row0 col0" >1.0</td>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row0_col1" class="data row0 col1" >0.66</td>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row0_col2" class="data row0 col2" >0.79</td>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row0_col3" class="data row0 col3" >0.39</td>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row0_col4" class="data row0 col4" >-0.0043</td>
#             </tr>
#             <tr>
#                         <th id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9level0_row1" class="row_heading level0 row1" >Engine_speed</th>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row1_col0" class="data row1 col0" >0.66</td>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row1_col1" class="data row1 col1" >1.0</td>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row1_col2" class="data row1 col2" >0.36</td>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row1_col3" class="data row1 col3" >0.77</td>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row1_col4" class="data row1 col4" >0.054</td>
#             </tr>
#             <tr>
#                         <th id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9level0_row2" class="row_heading level0 row2" >Calculated_LOAD_value</th>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row2_col0" class="data row2 col0" >0.79</td>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row2_col1" class="data row2 col1" >0.36</td>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row2_col2" class="data row2 col2" >1.0</td>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row2_col3" class="data row2 col3" >0.061</td>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9row2_col4" class="data row2 col4" >-0.11</td>
#             </tr>
#             <tr>
#                         <th id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9level0_row3" class="row_heading level0 row3" >Vehicle_speed</th>
#                         <td id="T_d5e4dc02_bbed_11e9_8e73_0c5415587dc9
#                         <td id="T_d60bc008_bbed_11e9_936f_0c5415587dc9row3_col3" class="data row3 col3" >1.0</td>
#                         <td id="T_d60bc008_bbed_11e9_936f_0c5415587dc9row3_col4" class="data row3 col4" >0.092</td>
#             </tr>
#             <tr>
#                         <th id="T_d60bc008_bbed_11e9_936f_0c5415587dc9level0_row4" class="row_heading level0 row4" >Time(s)</th>
#                         <td id="T_d60bc008_bbed_11e9_936f_0c5415587dc9row4_col0" class="data row4 col0" >-0.066</td>
#                         <td id="T_d60bc008_bbed_11e9_936f_0c5415587dc9row4_col1" class="data row4 col1" >0.061</td>
#                         <td id="T_d60bc008_bbed_11e9_936f_0c5415587dc9row4_col2" class="data row4 col2" >-0.16</td>
#                         <td id="T_d60bc008_bbed_11e9_936f_0c5415587dc9row4_col3" class="data row4 col3" >0.092</td>
#                         <td id="T_d60bc008_bbed_11e9_936f_0c5415587dc9row4_col4" class="data row4 col4" >1.0</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# There is a strong correlation between throttle position and engine speed, throttle position and engine load, engine speed and vehicle speed

# %%
#driver_A.isnull().values.any()
throttle_change_rate = np.diff(driver_A['Absolute_throttle_position'].values) 
throttle_change_rate =np.append(throttle_change_rate,driver_A.tail(1).Absolute_throttle_position.values)
es_change_rate = np.diff(driver_A['Engine_speed'].values)
es_change_rate = np.append(es_change_rate,driver_A.tail(1).Engine_speed.values)
vs_change_rate =  np.diff(driver_A['Vehicle_speed'].values)
vs_change_rate =  np.append(vs_change_rate,driver_A.tail(1).Vehicle_speed.values)
# Out:
# 7240

# %%
mod_relative_A = pd.DataFrame({'Throttle_change_rate':throttle_change_rate,'ES_change_rate':es_change_rate,'VS_change_rate':vs_change_rate,
                               'Engine_load':driver_A.Calculated_LOAD_value.values})

# %%
mod_relative_A.describe()
# Out:
#        Throttle_change_rate  ES_change_rate  VS_change_rate  Engine_load
# count           7240.000000     7240.000000     7240.000000  7240.000000
# mean               0.001727       -0.069751        0.000000    50.350981
# std               12.070355      240.442729        2.112135    22.124769
# min              -67.800000    -1875.000000      -14.000000     0.000000
# 25%               -0.400000      -51.000000       -1.000000    32.500000
# 50%                0.000000        0.000000        0.000000    51.000000
# 75%                0.800000       38.000000        1.000000    59.600000
# max               54.100000     2283.000000       11.000000    98.400000

# %%
g = sns.PairGrid(mod_relative_A)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
mod_relative_A.isnull().any()
# Out:
# Throttle_change_rate    False
# ES_change_rate          False
# VS_change_rate          False
# Engine_load             False
# dtype: bool

# %%
mod_relative_A.head()
# Out:
#    Throttle_change_rate  ES_change_rate  VS_change_rate  Engine_load
# 0                   0.4            -203               0         23.9
# 1                   0.0             -41               0         30.6
# 2                  -0.4             -10               0         31.8
# 3                   0.4              41               0         29.0
# 4                   0.0              24               0         30.2

# %% [markdown]
# Assumed vehicle max speed of 200 kph and engine speed of 6800 rpm

# %%
vehicle_speed_norm = [x/200 for x in driver_A['Vehicle_speed'].values]
engine_speed_norm = [x/6800 for x in driver_A['Engine_speed'].values]

# %%
rr_of_vs_and_es = [i/j for i,j in zip(vehicle_speed_norm, engine_speed_norm)]
len(rr_of_vs_and_es)
# Out:
# 7240

# %%
maximum_change_tp = max(mod_relative_A['Throttle_change_rate'].values)
maximum_change_es = max(mod_relative_A['ES_change_rate'].values)
throttle_position_norm = [x/maximum_change_tp for x in mod_relative_A['Throttle_change_rate'].values]
#len(throttle_position_norm)
es_relative_norm = [x/maximum_change_es for x in mod_relative_A['ES_change_rate'].values]
#len(es_relative_norm)
rr_of_tp_and_es = pd.Series([i/j for i,j in zip(throttle_position_norm, es_relative_norm)])
len(rr_of_tp_and_es)
#np.isneginf(rr_of_tp_and_es).any()
# Out:
# e:\envirocar\venv\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in double_scalars
#   import sys
# e:\envirocar\venv\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in double_scalars
#   import sys
# 7240

# %%
rr_of_tp_and_es.replace([np.inf,-np.inf], np.nan)
rr_of_tp_and_es.describe()
# Out:
# count    7035.000000
# mean             NaN
# std              NaN
# min             -inf
# 25%         0.000000
# 50%         0.000000
# 75%         1.179269
# max              inf
# dtype: float64

# %%
np.isinf(rr_of_tp_and_es).any()
# Out:
# True

# %%
feature_set_driverA = pd.DataFrame({'rr_of_vs_and_es':rr_of_vs_and_es,'rr_of_tp_and_es':rr_of_tp_and_es,'engine_load':mod_relative_A['Engine_load'].values})

# %%
feature_set_driverA.describe()
# Out:
#        rr_of_vs_and_es  rr_of_tp_and_es  engine_load
# count      7240.000000      7034.000000  7240.000000
# mean          0.606320              NaN    50.350981
# std           0.475529              NaN    22.124769
# min           0.000000             -inf     0.000000
# 25%           0.076902         0.000000    32.500000
# 50%           0.607503        -0.000000    51.000000
# 75%           0.989759         1.179629    59.600000
# max           2.054769              inf    98.400000

# %%
feature_set_driverA = feature_set_driverA[~feature_set_driverA.isin([np.nan, np.inf, -np.inf]).any(1)]
feature_set_driverA.tail()
# Out:
#       rr_of_vs_and_es  rr_of_tp_and_es  engine_load
# 7235              0.0         0.000000         43.5
# 7236              0.0         0.000000         43.9
# 7237              0.0        -2.813309         43.9
# 7238              0.0         0.073391         43.9
# 7239              0.0         2.567808          0.0

# %%
labels = []
for index, row in feature_set_driverA.iterrows():
    if (0.9 <= row['rr_of_vs_and_es']<= 1.3) and (0.9 <= row['rr_of_tp_and_es']<=1.3) and (20 <= row['engine_load'] <= 50):
        labels.append(1)
    else:
        labels.append(-1)

# %%
pd.Series(labels).describe()
# Out:
# count    7004.000000
# mean       -0.987150
# std         0.159807
# min        -1.000000
# 25%        -1.000000
# 50%        -1.000000
# 75%        -1.000000
# max         1.000000
# dtype: float64

# %%
feature_set_driverA['label'] = labels

# %%
data = feature_set_driverA[['rr_of_vs_and_es','rr_of_tp_and_es','engine_load']]
target = feature_set_driverA['label']

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Using cached https://files.pythonhosted.org/packages/1e/7a/dbb3be0ce9bd5c8b7e3d87328e79063f8b263b2b1bfa4774cb1147bfcd3f/sklearn-0.0.tar.gz
# Collecting scikit-learn (from sklearn)
#   Downloading https://files.pythonhosted.org/packages/76/79/60050330fe57fb59f2c53d0d11673df28c20ea9315da3652477429fc4949/scikit_learn-0.21.3-cp36-cp36m-win_amd64.whl (5.9MB)
# Requirement already satisfied: scipy>=0.17.0 in e:\envirocar\venv\lib\site-packages (from scikit-learn->sklearn) (1.3.0)
# Collecting joblib>=0.11 (from scikit-learn->sklearn)
#   Using cached https://files.pythonhosted.org/packages/cd/c1/50a758e8247561e58cb87305b1e90b171b8c767b15b12a1734001f41d356/joblib-0.13.2-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.11.0 in e:\envirocar\venv\lib\site-packages (from scikit-learn->sklearn) (1.16.4)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1322 sha256=14068eb89f0e957a376034de06f74cdcb8b7686f9ae827e659b99f4bc4356ada
#   Stored in directory: C:\Users\Lenovo\AppData\Local\pip\Cache\wheels\76\03\bb\589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# Installing collected packages: joblib, scikit-learn, sklearn
# Successfully installed joblib-0.13.2 scikit-learn-0.21.3 sklearn-0.0

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3)

# %%
adaboost_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)
# Train Adaboost Classifer
decision_tree_model = adaboost_classifier.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = decision_tree_model.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9990485252140818

# %%
driver_B.tail()
# Out:
#        Absolute_throttle_position  Engine_speed  Calculated_LOAD_value  \
# 84815                        13.7           670                   34.1
# 84816                        13.7           665                   34.1
# 84817                        13.7           669                   34.1
# 84818                        13.7           670                   34.1
# 84819                        13.7           663                   34.9
#
#        Vehicle_speed  Time(s) Class
# 84815              0     1972     B
# 84816              0     1973     B
# 84817              0     1974     B
# 84818              0     1975     B
# 84819              0     1976     B

# %%
driver_B.describe()
driver_B.isnull().values.any()
# Out:
# False

# %%
g = sns.PairGrid(driver_B)
g = g.map(plt.scatter)

# %%
driver_B.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row0_col1 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row0_col2 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row0_col3 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row1_col0 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row1_col2 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row1_col3 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row2_col0 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row2_col1 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row2_col3 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row3_col0 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row3_col1 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row3_col4 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row4_col0 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row4_col1 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row4_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Absolute_throttle_position</th>        <th class="col_heading level0 col1" >Engine_speed</th>        <th class="col_heading level0 col2" >Calculated_LOAD_value</th>        <th class="col_heading level0 col3" >Vehicle_speed</th>        <th class="col_heading level0 col4" >Time(s)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9level0_row0" class="row_heading level0 row0" >Absolute_throttle_position</th>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row0_col0" class="data row0 col0" >1.0</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row0_col1" class="data row0 col1" >0.52</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row0_col2" class="data row0 col2" >0.71</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row0_col3" class="data row0 col3" >0.32</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row0_col4" class="data row0 col4" >-0.048</td>
#             </tr>
#             <tr>
#                         <th id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9level0_row1" class="row_heading level0 row1" >Engine_speed</th>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row1_col0" class="data row1 col0" >0.52</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row1_col1" class="data row1 col1" >1.0</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row1_col2" class="data row1 col2" >0.16</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row1_col3" class="data row1 col3" >0.84</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row1_col4" class="data row1 col4" >0.019</td>
#             </tr>
#             <tr>
#                         <th id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9level0_row2" class="row_heading level0 row2" >Calculated_LOAD_value</th>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row2_col0" class="data row2 col0" >0.71</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row2_col1" class="data row2 col1" >0.16</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row2_col2" class="data row2 col2" >1.0</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row2_col3" class="data row2 col3" >-0.066</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row2_col4" class="data row2 col4" >-0.14</td>
#             </tr>
#             <tr>
#                         <th id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9level0_row3" class="row_heading level0 row3" >Vehicle_speed</th>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row3_col0" class="data row3 col0" >0.32</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row3_col1" class="data row3 col1" >0.84</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row3_col2" class="data row3 col2" >-0.066</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row3_col3" class="data row3 col3" >1.0</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row3_col4" class="data row3 col4" >0.079</td>
#             </tr>
#             <tr>
#                         <th id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9level0_row4" class="row_heading level0 row4" >Time(s)</th>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row4_col0" class="data row4 col0" >-0.048</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row4_col1" class="data row4 col1" >0.019</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row4_col2" class="data row4 col2" >-0.14</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row4_col3" class="data row4 col3" >0.079</td>
#                         <td id="T_3a4ab06e_bc58_11e9_abea_0c5415587dc9row4_col4" class="data row4 col4" >1.0</td>
#             </tr>
#     </tbody></table>

# %%
throttle_change_rate = np.diff(driver_B['Absolute_throttle_position'].values) 
print(len(throttle_change_rate))
es_change_rate = np.diff(driver_B['Engine_speed'].values)
vs_change_rate =  np.diff(driver_B['Vehicle_speed'].values)
# Out:
# 12863

# %%
len(driver_B.Calculated_LOAD_value.values[:len(driver_B.Calculated_LOAD_value.values)-1])
# Out:
# 12863

# %%
mod_relative_B = pd.DataFrame({'Throttle_change_rate':throttle_change_rate,'ES_change_rate':es_change_rate,'VS_change_rate':vs_change_rate,
                               'Engine_load':driver_B.Calculated_LOAD_value.values[:len(driver_B.Calculated_LOAD_value.values)-1]})

# %%
mod_relative_B.head()
mod_relative_B.isnull().any()
# Out:
# Throttle_change_rate    False
# ES_change_rate          False
# VS_change_rate          False
# Engine_load             False
# dtype: bool

# %%
vehicle_speed_norm = [x/200 for x in driver_B['Vehicle_speed'].values[:len(driver_B['Vehicle_speed'].values)-1]]
engine_speed_norm = [x/6800 for x in driver_B['Engine_speed'].values[:len(driver_B['Engine_speed'].values)-1]]
len(vehicle_speed_norm)
# Out:
# 12863

# %%
rr_of_vs_and_es = [i/j for i,j in zip(vehicle_speed_norm, engine_speed_norm)]
len(rr_of_vs_and_es)
# Out:
# 12863

# %%
maximum_change_tp = max(mod_relative_B['Throttle_change_rate'].values)
maximum_change_es = max(mod_relative_B['ES_change_rate'].values)
throttle_position_norm = [x/maximum_change_tp for x in mod_relative_B['Throttle_change_rate'].values]
#len(throttle_position_norm)
es_relative_norm = [x/maximum_change_es for x in mod_relative_B['ES_change_rate'].values]
#len(es_relative_norm)
rr_of_tp_and_es = pd.Series([i/j for i,j in zip(throttle_position_norm, es_relative_norm)])
len(rr_of_tp_and_es)
#np.isneginf(rr_of_tp_and_es).any()
# Out:
# e:\envirocar\venv\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in double_scalars
#   import sys
# e:\envirocar\venv\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in double_scalars
#   import sys
# 12863

# %%
rr_of_tp_and_es.describe()
rr_of_tp_and_es.replace([np.inf,-np.inf], np.nan)
#len(mod_relative_B['Engine_load'].values)
len(rr_of_tp_and_es)
# Out:
# 12863

# %%
feature_set_driverB = pd.DataFrame({'rr_of_vs_and_es':rr_of_vs_and_es,'rr_of_tp_and_es':rr_of_tp_and_es,'engine_load':mod_relative_D['Engine_load'].values})

# %%
feature_set_driverB.describe()
# Out:
#        rr_of_vs_and_es  rr_of_tp_and_es   engine_load
# count     12863.000000      12549.00000  12863.000000
# mean          0.542572              NaN     41.188525
# std           0.439454              NaN     17.930890
# min           0.000000             -inf     11.800000
# 25%           0.000000          0.00000     26.300000
# 50%           0.525967          0.00000     40.800000
# 75%           0.963563          0.67716     49.400000
# max           2.160748              inf     96.900000

# %%
feature_set_driverB = feature_set_driverB[~feature_set_driverB.isin([np.nan, np.inf, -np.inf]).any(1)]
feature_set_driverB.describe()
# Out:
#        rr_of_vs_and_es  rr_of_tp_and_es   engine_load
# count     12471.000000     12471.000000  12471.000000
# mean          0.555570         0.572509     41.102662
# std           0.436082        16.242985     17.928253
# min           0.000000      -421.426230     11.800000
# 25%           0.119299         0.000000     26.300000
# 50%           0.538766        -0.000000     40.400000
# 75%           0.966206         0.668533     49.200000
# max           2.160748       815.442623     96.900000

# %%
labels = []
for index, row in feature_set_driverB.iterrows():
    if (0.9 <= row['rr_of_vs_and_es']<= 1.3) and (0.9 <= row['rr_of_tp_and_es']<=1.3) and (20 <= row['engine_load'] <= 50):
        labels.append(1)
    else:
        labels.append(-1)

# %%
data = feature_set_driverB[['rr_of_vs_and_es','rr_of_tp_and_es','engine_load']]
target = labels

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3)

# %%
decision_tree_model.fit(X_train, y_train)
predictions = decision_tree_model.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.998663816141101

# %%
import pickle

# %%
filename = 'behaviour_analysis.sav'
pickle.dump(decision_tree_model,open(filename,'wb'))
