# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Extract 2017-07-05 data
car_data_05 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-05_Seat_Leon_RT_S_Stau.csv')
car_data_05_2 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-05_Seat_Leon_S_KA_Normal.csv')
car_data_06 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-06_Seat_Leon_KA_KA_Normal.csv')
car_data_06_2 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-06_Seat_Leon_KA_RT_Normal.csv')
car_data_07 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-07_Seat_Leon_RT_S_Normal.csv')
car_data_07_02 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-07_Seat_Leon_S_RT_Normal.csv')
car_data_10 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-10_Seat_Leon_KA_KA_Stau.csv')
car_data_11 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-11_Seat_Leon_KA_KA_Stau.csv')
car_data_11_02 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-11_Seat_Leon_KA_S_Normal.csv')
car_data_11_03 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-11_Seat_Leon_S_RT_Frei.csv')
car_data_12 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-12_Seat_Leon_RT_S_Normal.csv')
car_data_12_02 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-12_Seat_Leon_S_RT_Normal.csv')
car_data_13 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-13_Seat_Leon_KA_KA_Normal.csv')
car_data_13_02 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-13_Seat_Leon_RT_KA_Stau_Messfehler.csv')

# %%
car_data_05.dtypes
# Out:
# Time                                          object
# Engine Coolant Temperature [Â°C]               int64
# Intake Manifold Absolute Pressure [kPa]      float64
# Engine RPM [RPM]                             float64
# Vehicle Speed Sensor [km/h]                  float64
# Intake Air Temperature [Â°C]                 float64
# Air Flow Rate from Mass Flow Sensor [g/s]    float64
# Absolute Throttle Position [%]               float64
# Ambient Air Temperature [Â°C]                float64
# Accelerator Pedal Position D [%]             float64
# Accelerator Pedal Position E [%]             float64
# dtype: object

# %%
car_data_05['TripID'] = 1

# %%
#set(car_data_05.TripID.values)
#car_data_05_2.describe()
car_data_05_2['TripID'] = 2
#set(car_data_05_2.TripID.values)

# %%
time_pm = car_data_05_2.Time.values
time_pm[len(time_pm)-1]
# Out:
# '20:12:41.123'

# %%
car_data_05 = car_data_05.append(car_data_05_2, ignore_index=True)

# %%
#car_data_05.describe()
car_data_05 = car_data_05.dropna()
#car_data_05.describe()
#set(car_data_05.TripID.values)

# %%
car_data_05.columns
# Out:
# Index(['Time', 'Engine Coolant Temperature [Â°C]',
#        'Intake Manifold Absolute Pressure [kPa]', 'Engine RPM [RPM]',
#        'Vehicle Speed Sensor [km/h]', 'Intake Air Temperature [Â°C]',
#        'Air Flow Rate from Mass Flow Sensor [g/s]',
#        'Absolute Throttle Position [%]', 'Ambient Air Temperature [Â°C]',
#        'Accelerator Pedal Position D [%]', 'Accelerator Pedal Position E [%]',
#        'TripID'],
#       dtype='object')

# %%
time = car_data_05.Time.values
len(time)
# Out:
# 77148

# %%
def format_time(x,date):
    timestamp = date + ' ' + x
    return timestamp

# %%
timestamps = []
for x in time:
    ts = format_time(x,'2017-07-05')
    timestamps.append(ts)
len(timestamps)
# Out:
# 77148

# %%
from datetime import datetime
datetime_ts = [datetime.strptime(x,'%Y-%m-%d %H:%M:%S.%f') for x in timestamps]

# %%
#datetime_ts[len(datetime_ts) - 1]
car_data_05['Time'] = datetime_ts

# %%
set(car_data_05.TripID.values)
# Out:
# {1, 2}

# %% [markdown]
# Date = 2017/07/06

# %%
#car_data_06.dtypes
car_data_06['TripID'] = 1
car_data_06_2['TripID'] = 2

# %%
#set(car_data_06_2.TripID.values)
car_data_06 = car_data_06.append(car_data_06_2, ignore_index=True)

# %%
#car_data_06.describe()
#set(car_data_06.TripID.values)
car_data_06 = car_data_06.dropna()
car_data_06.describe()
# Out:
#        Engine Coolant Temperature [Â°C]  \
# count                      75342.000000
# mean                          83.720660
# std                           15.936306
# min                           28.000000
# 25%                           90.000000
# 50%                           91.000000
# 75%                           91.000000
# max                           96.000000
#
#        Intake Manifold Absolute Pressure [kPa]  Engine RPM [RPM]  \
# count                             75342.000000      75342.000000
# mean                                128.031616       1465.168870
# std                                  33.308730        593.848915
# min                                  36.000000          0.000000
# 25%                                 104.000000       1024.000000
# 50%                                 115.000000       1498.000000
# 75%                                 142.000000       1922.000000
# max                                 236.000000       3072.000000
#
# ...

# %%
time = car_data_06.Time.values
timestamps = []
for x in time:
    ts = format_time(x,'2017-07-06')
    timestamps.append(ts)
datetime_ts = [datetime.strptime(x,'%Y-%m-%d %H:%M:%S.%f') for x in timestamps]
car_data_06['Time'] = datetime_ts

# %%
set(car_data_06.TripID.values)
# Out:
# {1, 2}

# %% [markdown]
# Date = 2017-07-07

# %%
#car_data_07.describe()
car_data_07['TripID'] = 1
car_data_07_02['TripID'] =2

# %%
#set(car_data_07_02.TripID.values)
car_data_07 = car_data_07.append(car_data_07_02, ignore_index=True)

# %%
#car_data_07.describe()
#set(car_data_07.TripID.values)
car_data_07 = car_data_07.dropna()
car_data_07.describe()
# Out:
#        Engine Coolant Temperature [Â°C]  \
# count                      65368.000000
# mean                          86.580926
# std                           11.386730
# min                           31.000000
# 25%                           90.000000
# 50%                           91.000000
# 75%                           91.000000
# max                           94.000000
#
#        Intake Manifold Absolute Pressure [kPa]  Engine RPM [RPM]  \
# count                             65368.000000      65368.000000
# mean                                125.056419       1501.195937
# std                                  28.163821        401.535339
# min                                  36.000000          0.000000
# 25%                                 105.000000       1314.000000
# 50%                                 114.000000       1516.000000
# 75%                                 137.000000       1759.000000
# max                                 230.000000       2645.000000
#
# ...

# %%
time = car_data_07.Time.values
timestamps = []
for x in time:
    ts = format_time(x,'2017-07-07')
    timestamps.append(ts)
datetime_ts = [datetime.strptime(x,'%Y-%m-%d %H:%M:%S.%f') for x in timestamps]
car_data_07['Time'] = datetime_ts

# %%
set(car_data_07.TripID.values)
# Out:
# {1, 2}

# %% [markdown]
# Date = 2017/07/10

# %%
car_data_10['TripID'] = 1

# %%
#set(car_data_10.TripID.values)
car_data_10 = car_data_10.dropna()
car_data_10.describe()
# Out:
#        Engine Coolant Temperature [Â°C]  \
# count                      14561.000000
# mean                          90.622897
# std                            0.673290
# min                           90.000000
# 25%                           90.000000
# 50%                           91.000000
# 75%                           91.000000
# max                           92.000000
#
#        Intake Manifold Absolute Pressure [kPa]  Engine RPM [RPM]  \
# count                             14561.000000      14561.000000
# mean                                106.576677        940.975620
# std                                  14.201539        565.845928
# min                                  37.000000          0.000000
# 25%                                 102.000000        789.000000
# 50%                                 105.000000        912.000000
# 75%                                 109.000000       1328.000000
# max                                 222.000000       3109.000000
#
# ...

# %%
time = car_data_10.Time.values
timestamps = []
for x in time:
    ts = format_time(x,'2017-07-10')
    timestamps.append(ts)
datetime_ts = [datetime.strptime(x,'%Y-%m-%d %H:%M:%S.%f') for x in timestamps]
car_data_10['Time'] = datetime_ts

# %%
set(car_data_10.TripID.values)
# Out:
# {1}

# %% [markdown]
# Date = 2017-07-11

# %%
car_data_11['TripID'] = 1
car_data_11_02['TripID'] =2
car_data_11_03['TripID'] = 3

# %%
#set(car_data_11_03.TripID.values)
car_data_11 = car_data_11.append(car_data_11_02, ignore_index=True)
car_data_11 = car_data_11.append(car_data_11_03, ignore_index=True)

# %%
#set(car_data_11.TripID.values)
#car_data_11.describe()
car_data_11 = car_data_11.dropna()
car_data_11.describe()
# Out:
#        Engine Coolant Temperature [Â°C]  \
# count                      87071.000000
# mean                          84.949696
# std                           14.355382
# min                           24.000000
# 25%                           90.000000
# 50%                           91.000000
# 75%                           91.000000
# max                           94.000000
#
#        Intake Manifold Absolute Pressure [kPa]  Engine RPM [RPM]  \
# count                             87071.000000      87071.000000
# mean                                123.564045       1426.562242
# std                                  35.343939        555.253083
# min                                  36.000000          0.000000
# 25%                                 102.000000        955.000000
# 50%                                 112.000000       1484.000000
# 75%                                 135.000000       1790.000000
# max                                 242.000000       3563.000000
#
# ...

# %%
time = car_data_11.Time.values
timestamps = []
for x in time:
    ts = format_time(x,'2017-07-11')
    timestamps.append(ts)
datetime_ts = [datetime.strptime(x,'%Y-%m-%d %H:%M:%S.%f') for x in timestamps]
car_data_11['Time'] = datetime_ts

# %%
set(car_data_11.TripID.values)
# Out:
# {1, 2, 3}

# %% [markdown]
# Date = 2017-07-12

# %%
car_data_12 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-12_Seat_Leon_RT_S_Normal.csv')
car_data_12_02 = pd.read_csv(r'E:\Envirocar\analysis\2017-07-12_Seat_Leon_S_RT_Normal.csv')
car_data_12['TripID'] = 1
car_data_12_02['TripID'] =2

# %%
#set(car_data_12_02.TripID.values)
car_data_12 = car_data_12.append(car_data_12_02, ignore_index=True)

# %%
set(car_data_12.TripID.values)
#car_data_12.describe()
car_data_12 = car_data_12.dropna()
car_data_12.describe()
# Out:
#        Engine Coolant Temperature [Â°C]  \
# count                      75607.000000
# mean                          84.186041
# std                           15.094771
# min                           29.000000
# 25%                           90.000000
# 50%                           90.000000
# 75%                           91.000000
# max                           94.000000
#
#        Intake Manifold Absolute Pressure [kPa]  Engine RPM [RPM]  \
# count                             75607.000000      75607.000000
# mean                                119.632362       1418.576693
# std                                  25.165434        461.019267
# min                                  36.000000          0.000000
# 25%                                 103.000000       1162.000000
# 50%                                 112.000000       1483.000000
# 75%                                 127.000000       1733.000000
# max                                 228.000000       2880.000000
#
# ...

# %%
time = car_data_12.Time.values
timestamps = []
for x in time:
    ts = format_time(x,'2017-07-12')
    timestamps.append(ts)
datetime_ts = [datetime.strptime(x,'%Y-%m-%d %H:%M:%S.%f') for x in timestamps]
car_data_12['Time'] = datetime_ts
len(car_data_12.Time.values)
# Out:
# 75607

# %%
set(car_data_12.TripID.values)
# Out:
# {1, 2}

# %% [markdown]
# Date = 2017-07-13

# %%
car_data_13['TripID'] = 1
car_data_13_02['TripID'] =2

# %%
#set(car_data_13_02.TripID.values)
car_data_13 = car_data_13.append(car_data_13_02, ignore_index=True)

# %%
#car_data_13.describe()
car_data_13 = car_data_13.dropna()
car_data_13.describe()
# Out:
#        Engine Coolant Temperature [Â°C]  \
# count                      70832.000000
# mean                          86.050104
# std                           12.601947
# min                           30.000000
# 25%                           90.000000
# 50%                           90.000000
# 75%                           91.000000
# max                           94.000000
#
#        Intake Manifold Absolute Pressure [kPa]  Engine RPM [RPM]  \
# count                             70832.000000      70832.000000
# mean                                128.492842       1440.836486
# std                                  36.542749        696.815153
# min                                  36.000000          0.000000
# 25%                                 104.000000        907.000000
# 50%                                 113.000000       1481.000000
# 75%                                 139.000000       1939.000000
# max                                 236.000000       3658.000000
#
# ...

# %%
time = car_data_13.Time.values
timestamps = []
for x in time:
    ts = format_time(x,'2017-07-13')
    timestamps.append(ts)
datetime_ts = [datetime.strptime(x,'%Y-%m-%d %H:%M:%S.%f') for x in timestamps]
car_data_13['Time'] = datetime_ts

# %%
set(car_data_13.TripID.values)
# Out:
# {1, 2}

# %%
driving_data = car_data_05
driving_data = driving_data.append(car_data_06, ignore_index=True)
driving_data = driving_data.append(car_data_07, ignore_index=True)
driving_data = driving_data.append(car_data_10, ignore_index=True)
driving_data = driving_data.append(car_data_11, ignore_index=True)
driving_data = driving_data.append(car_data_12, ignore_index=True)
driving_data = driving_data.append(car_data_13, ignore_index=True)

# %%
set(driving_data.TripID.values)
#driving_data.describe()
#driving_data.head()
driving_data.Time = driving_data.Time.astype('str')

# %%
driving_data.head(10)
# Out:
#                       Time  Engine Coolant Temperature [Â°C]  \
# 0  2017-07-05 07:16:31.257                                31
# 1  2017-07-05 07:16:31.345                                31
# 2  2017-07-05 07:16:31.435                                31
# 3  2017-07-05 07:16:31.525                                31
# 4  2017-07-05 07:16:31.615                                31
# 5  2017-07-05 07:16:31.705                                31
# 6  2017-07-05 07:16:31.795                                31
# 7  2017-07-05 07:16:31.886                                31
# 8  2017-07-05 07:16:31.975                                31
# 9  2017-07-05 07:16:32.065                                31
#
#    Intake Manifold Absolute Pressure [kPa]  Engine RPM [RPM]  \
# 0                                     96.0               0.0
# 1                                     96.0               0.0
# 2                                     96.0               0.0
# ...

# %% [markdown]
# ### Export Driving Data to database

# %%
from sqlalchemy import create_engine

# %%
conn = create_engine('sqlite:///E:/Envirocar/myapp/envirocar.db')

# %%
driving_data.to_sql('VehicleData',conn, index=False, chunksize=5000)
